# %%
import ee 
import folium
import geehydro
import json
import requests
from datetime import datetime as dt
from IPython.display import Image

phoenix_buildings = json.load(open("LiDAR-Derived_3D_Building_Footprints_-_metro-Phoenix_(2014).geojson"))

phoenix_buildings.keys()

#for i in range(len(phoenix_buildings['features'])):
    
    #if all_parcels['features'][i]['properties']['CITY'] == 'PHOENIX':
    #    phoenix_parcels.append(all_parcels['features'][i])
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])

# %%
phoenix_buildings
# Out:
# {'type': 'FeatureCollection',
#  'name': 'LiDAR-Derived_3D_Building_Footprints_-_metro-Phoenix_(2014)',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'FID': 1,
#     'TOPELEV_M': 541.57,
#     'BASEELEV_M': 536.58,
#     'HGT_AGL': 4.99,
#     'MED_SLOPE': 18,
#     'ROOFTYPE': 'Pitched',
#     'SSR': 42,
#     'ID': 50331,
#     'BLDGID': 53456,
#     'AREA_M2': 457.349,
#     'AVGHT_M': 4.59,
#     'MINHT_M': 0.0,
#     'MAXHT_M': 6.8,
#     'BASE_M': 536.8,
#     'ORIENT8': -14.6,
#     'LEN': 24.8,
#     'WID': 21.86,
#     'CITY': 'Phoenix_AZ',
#     'Shape__Area': 662.59765625,
#     'Shape__Length': 149.904251257531},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.912409862097, 33.6805473725162],
#       [-111.912442904746, 33.6805543599244],
#       [-111.912485358188, 33.6805633368568],
#       [-111.912531066065, 33.6805730022382],
# ...

# %%
phoenix_buildings['features'][1]['properties']['CITY']

k = 0

for i in range(len(phoenix_buildings['features'])):
    if phoenix_buildings['features'][i]['properties']['CITY'] == 'Phoenix_AZ':
        k = k+1
        
k
# Out:
# 852008

# %%
import pandas 

phoenix_buildings_subset = []

for i in range(100):
    if phoenix_buildings['features'][i]['properties']['CITY'] == 'Phoenix_AZ':
        phoenix_buildings_subset.append(phoenix_buildings['features'][i])

        
new_json = dict.fromkeys(['type','features'])
new_json['type'] = 'FeatureCollection'
new_json['features'] = phoenix_buildings_subset


phoenix_map = folium.Map(location=[33.4484, -112.0740], zoom_start=7)

folium.GeoJson(new_json, name = "buildings").add_to(phoenix_map)
folium.LayerControl().add_to(phoenix_map)


phoenix_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
